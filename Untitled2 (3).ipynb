# %%
import pandas as pd
import numpy as np

# %%
# !pip install sentence_transformers

# %%
from sentence_transformers import SentenceTransformer, util

# %%
question_bank = [
      #{"question":"چرا همیشه اضطراب دارم؟ "or"همیشه اضطراب دارم و نمی‌دونم چرا","answer":"اضطراب می‌تونه از استرس زیاد یا نگرانی‌های بی‌پایان باشه. باید یاد بگیری که چطور با اون روبه‌رو بشی"},
      {"question":"چطور می‌تونم با استرس کنترل شده زندگی کنم؟ "or"نمی‌تونم استرس‌هام رو کنترل کنم و همیشه احساس نگرانی دارم","answer":"تمرین‌های تنفس عمیق و مدیتیشن کمک زیادی می‌کنه"},
      {"question":"احساس می‌کنم هیچ‌چیز رو نمی‌تونم کنترل کنم","answer":"خیلی‌ها اینطور احساس می‌کنن. مهم اینه که کم‌کم چیزهای کوچیکی که می‌تونی کنترل کنی رو شناسایی کنی"},
      {"question":"چرا هیچوقت از خودم راضی نیستم؟"or"هیچ‌وقت از خودم راضی نیستم و همیشه فکر می‌کنم که باید بهتر باشم","answer":"ممکنه انتظاراتت از خودت خیلی بالاتر از توان واقعیت باشه. به خودت فرصت رشد بده"},
      {"question":"وقتی عصبی می‌شم، هیچ چیزی رو نمی‌بینم"or"خیلی زود عصبی میشم","answer":"عصبانیت می‌تونه پرده‌ای جلوی چشممون بکشه. وقتی عصبی شدی، لحظه‌ای صبر کن و نفس عمیق بکش"},
      {"question":"چرا نمی‌تونم به دیگران اعتماد کنم؟ "or"هیچ‌وقت نمی‌توانم به دیگران اعتماد کنم و همیشه این احساس رو دارم که بهم خیانت می‌کنند","answer":"شاید تجاربی داشته‌ای که باعث شده احساس کنی که مردم قابل اعتماد نیستند. به خودت زمان بده تا دوباره بازسازی کنی"},
      {"question":"چطور می‌توانم مثبت‌ تر فکر کنم؟ "or"خیلی سعی می‌کنم که مثبت فکر کنم، اما باز هم افکار منفی به سراغم میاد","answer":"هر روز ۳ مورد خوب رو بنویس و از خودت بپرس چه چیزهایی در زندگی‌ات خوبه"},
      {"question":"چه چیزی باعث میشه من دائم مقایسه کنم خودم رو با دیگران؟"or"همیشه خودم رو با دیگران مقایسه می‌کنم و احساس می‌کنم که کافی نیستم","answer":"ممکنه به خودت اعتماد نداری و این باعث میشه به زندگی دیگران نگاه کنی. تلاش کن روی ویژگی‌ها و دستاوردهای خودت تمرکز کنی"},
      {"question":"چرا گاهی اوقات احساس می‌کنم هیچ هدفی ندارم؟ "or"گاهی اوقات احساس می‌کنم که هیچ هدفی در زندگی ندارم و نمی‌دونم باید چه کاری انجام بدم","answer":"این حس ممکنه به دلیل نبود شفافیت در زندگی یا اهداف مبهم باشه. به مرور و با شفاف‌سازی می‌تونی هدف‌های مشخصی پیدا کنی"},
      {"question":"چطور می‌تونم از افکار منفی رها بشم؟ "or"هر وقت سعی می‌کنم از افکار منفی خلاص بشم، نمی‌توانم و باز هم به ذهنم برمی‌گردند","answer":"اولین قدم اینه که افکارتو شناسایی کنی. بعد، اون‌ها رو با افکار مثبت و واقع‌بینانه جایگزین کن"},
      {"question":"چرا بعضی وقت‌ها نمی‌تونم خوشحال باشم؟ "or"حتی وقتی که همه چیز خوب پیش می‌رود، نمی‌توانم خوشحال باشم و همیشه یه چیزی کم دارم","answer":"شاید درگیر افکار یا شرایط سختی هستی. شاید به کمک نیاز داری تا به خودت بازگردی"},
      {"question":"جگونه میتوانم راحت استراحت کنم؟"or"همیشه احساس می‌کنم که نمی‌توانم استراحت کنم و ذهنم مدام درگیر است","answer":"وقتی خیلی مشغولیم، ذهن و بدن نیاز به استراحت دارن. سعی کن زمان‌هایی برای ریلکسیشن داشته باشی"},
      {"question":"چطور می‌توانم از افسردگی خلاص بشم؟"or" احساس افسردگی دارم و نمی‌دانم چطور می‌توانم از این وضعیت بیرون بیام","answer":"افسردگی نیاز به درمان داره. درمان می‌تواند شامل مشاوره، دارو یا هر دو باشه"},
      {"question":"چطور می‌توانم بیشتر شجاع باشم؟ "or"سعی می‌کنم شجاع باشم، اما همیشه ترس و تردید دارم و نمی‌توانم گام‌های بزرگ بردارم","answer":"شجاعت، یعنی انجام کارها حتی وقتی که می‌ترسی. با هر گام کوچکی که برمی‌داری، شجاعتت بیشتر میشه"},
      {"question":"چرا احساس می‌کنم هیچ‌کس منو درک نمی‌کنه؟"or"احساس می‌کنم هیچ‌کس نمی‌تونه منو درک کنه و همیشه احساس تنهایی می‌کنم","answer":"ین حس می‌تواند ناشی از عدم ارتباط موثر باشه. تلاش کن با دیگران به شیوه‌ای بازتر و صادقانه صحبت کنی"},
      {"question":"چطور می‌توانم آرامش درونی پیدا کنم؟"or"هر وقت سعی می‌کنم آرامش پیدا کنم، نمی‌توانم و ذهنم همواره مشغول است","answer":"آرامش درونی از درون شروع میشه. ذهن تو باید بی‌وقفه آرام بشه، با تمرین‌هایی مثل مدیتیشن"},
      {"question":" چرا من همیشه باید کنترل همه‌چیز رو داشته باشم؟"or" همیشه احساس می‌کنم که باید همه چیز رو کنترل کنم و نمی‌توانم رها کنم","answer":"نیاز به کنترل می‌تونه به خاطر ترس از عدم امنیت باشه. سعی کن بعضی چیزها رو رها کنی و به دیگران اعتماد کنی"},
      {"question":"چطور می‌توانم از شکست نترسم؟"or"هر بار که با شکست مواجه می‌شم، احساس می‌کنم هیچ چیزی ارزش نداره و نمی‌توانم از اون عبور کنم","answer":"شکست یه تجربه آموزنده‌است. با هر اشتباه، فرصت یادگیری داری"},
      {"question:":"چرا احساس می‌کنم هیچ وقت نمی‌توانم چیزی را تمام کنم؟"or"حتی وقتی تمام تلاشم رو می‌کنم، همیشه احساس می‌کنم که نمی‌توانم چیزی رو تمام کنم","answer":"شاید به دلیل ترس از شکست یا کمال‌گرایی باشه. تمرکز روی مراحل کوچکتر بهت کمک می‌کنه"},
      {"question":"چرا گاهی اوقات احساس بی‌ارزشی می‌کنم؟"or"هیچ وقت از خودم راضی نیستم و فکر می‌کنم همیشه باید بیشتر تلاش کنم","answer":"ممکنه خودت رو با استانداردهای غیرواقعی مقایسه کنی. باید خودت رو بپذیری به همون شکلی که هستی"},
      {"question":"آیا افسردگی قابل درمان است؟"or"همیشه احساس می‌کنم که افسردگی من درمان‌پذیر نیست و هیچ راهی برای بهبود وجود ندارد","answer":"افسردگی قابل درمانه. درمان می‌تواند به کمک روانشناسی، دارو یا ترکیبی از این‌ها باشه"},
      {"question":"چرا گاهی در جمع احساس غریبگی می‌کنم؟"or"وقتی در جمع قرار می‌گیرم، همیشه احساس می‌کنم که جایی برای من وجود ندارد و غریبم","answer":"این ممکنه ناشی از عدم اعتماد به نفس باشه. تمرین کردن در موقعیت‌های اجتماعی می‌تونه بهت کمک کنه"},
      {"question":"چطور می‌توانم بیشتر با خودم مهربان باشم؟"or"هیچ‌وقت نتونستم با خودم مهربون باشم و همیشه خودم رو سرزنش می‌کنم","answer":"یاد بگیر خودت رو به اندازه دیگران دوست داشته باشی و از خودت انتقاد نکن"},
      {"question":"چرا همیشه احساس خستگی می‌کنم؟"or"همیشه احساس خستگی دارم و نمی‌دانم چرا هیچ‌وقت انرژی کافی ندارم","answer":"می‌توانم خودم را به خوبی بشناسم و همیشه در جستجوی خودم هستم"},
      {"question":"چطور می‌توانم خودم را بیشتر بشناسم؟"or"نمی‌توانم خودم را به خوبی بشناسم و همیشه در جستجوی خودم هستم","answer":"خودشناسی با تفکر و بررسی رفتارها و احساسات به‌دست میاد. خودت رو در موقعیت‌های مختلف آزمایش کن"},
      {"question":"چرا همیشه از آینده می‌ترسم؟"or"همیشه از آینده می‌ترسم و نمی‌توانم به جلو نگاه کنم","answer":"ترس از آینده به دلیل عدم قطعیت به وجود میاد. تمرکز روی حال و اقدام‌های کوچیک می‌تونه کمکت کنه"},
      {"question":"چرا گاهی احساس می‌کنم هیچ‌چیز تغییر نمی‌کنه؟"or"هرچه می‌زنم جلوتر، احساس می‌کنم که هیچ‌چیز تغییر نمی‌کند و درجا می‌زنم","answer":"تغییر ممکنه کند و نامحسوس باشه. با پیگیری مداوم، تغییرات کوچیک جمع می‌شوند و بزرگ می‌شوند"},
      {"question":"چرا بعضی وقت‌ها نمی‌توانم از دیگران فاصله بگیرم؟"or"هیچ‌وقت نمی‌توانم از دیگران فاصله بگیرم و همیشه وابسته به روابط هستم","answer":"این می‌تواند به دلیل وابستگی عاطفی یا ترس از تنهایی باشه. به تدریج مرزهای سالم ایجاد کن"},
      {"question":"چطور می‌توانم احساس آرامش پیدا کنم وقتی همه‌چیز به هم ریخته است؟"or"حتی وقتی همه چیز بهم ریخته، نمی‌توانم آرامش پیدا کنم و همیشه استرس دارم","answer":"یک قدم در هر زمان. ابتدا تمرکز کن روی نفس کشیدن و سپس اولویت‌بندی مشکلات"},
      {"question":"چرا بعضی وقت‌ها احساس می‌کنم از همه چیز خسته شدم؟"or"احساس می‌کنم هیچ‌چیز تغییر نمی‌کنه و هیچ‌وقت نمی‌توانم به وضعیت بهتری برسم","answer":"ممکنه به دلیل فشارهای روزمره یا عدم استراحت کافی باشه. باید به خودت استراحت بدی"},
      {"question":"چطور می‌توانم بیشتر به خودم احترام بگذارم؟"or"نمی‌توانم به خودم احترام بگذارم و همیشه خودم رو پایین‌تر از دیگران می‌بینم","answer":"با خودت مهربون باش. از خودت مراقبت کن و برای خودت ارزش قائل شو"},
      {"question":"من تنها هستم؟"or"همیشه احساس تنهایی دارم، حتی وقتی در جمع هستم","answer":"اهی اوقات افراد احساس تنهایی می‌کنند، اما این احساس دائمی نیست. روابط جدید و حمایت می‌تواند کمکت کنه"},
      {"question":"چرا نمی‌توانم هیچ‌وقت خوشحال باشم؟"or"حتی وقتی همه چیز به نظر خوب میاد، نمی‌توانم خوشحال باشم و همیشه چیزی کم دارم","answer":"شاید به دنبال خوشبختی در جاهایی هستی که نمی‌توانی پیدا کنی. سعی کن لحظه‌های ساده زندگی رو قدر بدانی"},
      {"question":"چطور می‌توانم از نگرانی‌های بی‌پایان رها بشم؟"or"همیشه نگرانی‌های بی‌پایان دارم و هیچ‌وقت نمی‌توانم از اون‌ها رها بشم","answer":"نگرانی‌ها زمانی تشدید می‌شن که بهشون توجه بیشتری بدی. تمرین کن که به جای نگرانی، عمل کنی"},
      {"question":"چرا فکر می‌کنم همه چیز باید کامل باشه؟"or"همیشه فکر می‌کنم که باید همه چیز کامل باشه و هیچ چیزی نباید ناقص باشه","answer":" کمال‌گرایی می‌تواند فشار زیادی به خودت وارد کنه. یاد بگیر که چیزها به‌صورت ناقص هم می‌توانند ارزشمند باشند"},
      {"question":"چطور می‌توانم با پشیمانی‌های گذشته کنار بیام؟"or"هیچ‌وقت نمی‌توانم با پشیمانی‌هایم کنار بیام و همیشه اون‌ها رو در ذهنم مرور می‌کنم","answer":"پشیمانی بخشی از زندگی است. از آن به عنوان فرصتی برای یادگیری استفاده کن و خودت رو ببخش"},
      {"question":"چطور می‌توانم از ترس‌های بی‌دلیل رها بشم؟"or"همیشه از ترس‌هایی که ندارم رنج می‌برم و هیچ‌وقت نمی‌توانم از شر اون‌ها خلاص بشم","answer":"ترس‌ها اغلب از افکار منفی ناشی میشن. وقتی این افکار رو شناسایی کنی، می‌تونی آن‌ها رو تغییر بدی"},
      {"question":"چرا گاهی احساس می‌کنم هیچ‌چیز نمی‌ارزد؟"or"همیشه احساس می‌کنم که هیچ‌چیز ارزش ندارد و هیچ‌وقت نمی‌توانم از این وضعیت بیرون بیام","answer":"ممکنه درگیر افکار منفی شده باشی. سعی کن روی دستاوردها و نقاط قوت خودت تمرکز کنی"},
      {"question":"چرا هیچ وقت از خودم راضی نیستم؟"or"هیچ‌وقت از خودم راضی نیستم و همیشه احساس می‌کنم که باید بیشتر و بهتر باشم","answer":"ممکنه استانداردهای غیرواقعی از خودت داشته باشی. با پذیرش خودت، می‌تونی بیشتر از خودت راضی باشی"},
      {"question":"چطور می‌توانم مهارت‌های اجتماعی بهتری داشته باشم؟"or"در روابط اجتماعی همیشه احساس می‌کنم که نمی‌توانم ارتباطات خوبی برقرار کنم و همیشه تحت فشارم","answer":"تمرین و تجربه در موقعیت‌های اجتماعی بهت کمک می‌کنه تا ارتباطات بهتری برقرار کنی"},
      {"question":"چرا نمی‌توانم از کارم لذت ببرم؟"or" هیچ‌وقت نمی‌توانم از کارم لذت ببرم و همیشه احساس می‌کنم که کارم بی‌هدف است","answer":"شاید به دلیل عدم تطابق شغلت با علاقه‌هات باشه. بررسی کن که آیا شغلت با ارزش‌ها و علایق شخصی‌ت همخوانیه"},
      {"question":"چطور می‌توانم با خودم صادق باشم؟"or"نمی‌توانم با خودم صادق باشم و همیشه احساس می‌کنم که از خودم فرار می‌کنم","answer":"باید خودت رو بدون هیچ‌گونه قضاوتی بپذیری. از درون با خودت گفتگو کن و حقیقت رو بشنو"},
      {"question":"چطور می‌توانم با ناکامی‌ها کنار بیام؟"or"همیشه نمی‌توانم با ناکامی‌ها کنار بیام و فکر می‌کنم که شکست من را تعریف می‌کند","answer":"اکامی‌ها بخشی از مسیر هستند. یاد بگیر از آن‌ها برای رشد و پیشرفت استفاده کنی"},
      {"question":" چرا بعضی وقت‌ها احساس می‌کنم هیچ‌چیز درست نمی‌شود؟"or"هیچ‌وقت نمی‌توانم از گذشته رها بشم و همیشه درگیر اشتباهات و تصمیمات قبلیم هستم","answer":"گاهی اوقات به دلیل عدم صبر یا شرایط دشوار این احساس به‌وجود میاد. با تغییر نگاه، می‌توانی امید را پیدا کنی"},
      {"question":"چرا همیشه احساس می‌کنم برای دیگران کافی نیستم؟","answer":"شاید به دلیل انتظارات زیاد از خودت باشه. خودت رو به خاطر همون چیزی که هستی دوست داشته باش"},
      {"question":"چطور می‌توانم اعتماد به نفس خودم رو افزایش بدم؟"or"هیچ‌وقت نمی‌توانم اعتماد به نفس پیدا کنم و همیشه از خودم مطمئن نیستم","answer":"تمرین روزانه، یادگیری از تجربیات و پذیرش خودت می‌تونه کمک‌کننده باشه"},
      {"question":"چرا وقتی با دیگران مقایسه می‌کنم، خودم رو شکست خورده می‌بینم؟"or"همیشه خودم رو با دیگران مقایسه می‌کنم و احساس می‌کنم که هیچ‌وقت به اندازه آن‌ها خوب نیستم","answer":"مقایسه همیشه منصفانه نیست. هر کسی داستان زندگی متفاوتی داره و این باید مورد توجه قرار بگیره"},
      {"question":"چرا گاهی اوقات در برابر تغییر مقاومت می‌کنم؟"or"همیشه از تغییر می‌ترسم و نمی‌توانم با اون کنار بیام","answer":"ترس از ناشناخته‌ها یا از دست دادن امنیت می‌تونه عامل مقاومت در برابر تغییر باشه. تلاش کن آرام‌آرام با تغییرات روبه‌رو بشی"},
      {"question":"چرا گاهی نمی‌توانم تصمیم درستی بگیرم؟"or"نمی‌توانم تصمیمات درستی بگیرم و همیشه در تردید هستم","answer":"شاید به خاطر ترس از اشتباه باشه. به خودت اعتماد کن و یاد بگیر که تصمیمات هرچند کوچک هم می‌توانند تأثیرگذار باشند"},
      {"question":"چطور می‌توانم بیش از پیش از لحظات زندگی لذت ببرم؟"or"همیشه احساس می‌کنم که هیچ‌چیز به درستی پیش نمی‌رود و هیچ‌وقت موفق نمی‌شوم","answer":"تمرکز بر لحظه‌ها و سپاس‌گذاری برای چیزهای کوچک می‌تواند بهت کمک کند بیشتر لذت ببری"},
      {"question":"چرا در روابط شخصی همیشه احساس بی‌اعتمادی می‌کنم؟","answer":"ممکنه به خاطر تجربیات گذشته باشه. باید قدم به قدم به دیگران اعتماد کنی"},
      {"question":"چرا احساس می‌کنم هیچ‌کس نمی‌فهمه من چطور احساس می‌کنم؟","answer":"شاید به خاطر ارتباط ضعیف یا عدم بیان احساسات باشه. سعی کن با دیگران به‌طور شفاف‌تر صحبت کنی"},
      {"question":"چطور می‌توانم بهتر به نیازهای عاطفی خودم توجه کنم؟"or"نمی‌توانم به نیازهای عاطفی خودم توجه کنم و همیشه خودم رو نادیده می‌گیرم","answer":"باید یاد بگیری که به خودت گوش بدی و زمانی برای خودت اختصاص بدی"},
      {"question":"چطور می‌توانم در موقعیت‌های استرس‌زا آرام بمونم؟"or"همیشه نمی‌توانم در موقعیت‌های استرس‌زا آرام باشم و ذهنم مدام درگیر است","answer":"تکنیک‌های تنفس و تمرکز بر حال می‌تونه بهت کمک کنه آرامش پیدا کنی"},
      {"question":"چرا من همیشه از اشتباه کردن می‌ترسم؟"or"نمی‌توانم اشتباهات خودم رو بپذیرم و همیشه از اشتباه کردن می‌ترسم","answer":"اشتباهات بخش طبیعی از یادگیری‌اند. نباید از آن‌ها فرار کنی، بلکه باید از آن‌ها استفاده کنی"},
      {"question":"چطور می‌توانم بدون مقایسه زندگی کنم؟"or"همیشه احساس می‌کنم که در زندگی هیچ‌چیز کامل نیست و همه‌چیز ناقص است","answer":"سعی کن به زندگی خودت و دستاوردهای خودت توجه کنی، نه به آنچه که دیگران دارند"},
      {"question":"چطور می‌توانم افکار منفی خودم رو تغییر بدم؟"or"همیشه به خودم فشار می‌آورم و نمی‌توانم از خودم راضی باشم","answer":"افکار منفی رو شناسایی کن و سعی کن به جای اون‌ها، افکار مثبت و سازنده بیاری"},
      {"question":"چرا بعضی وقت‌ها از خودم فرار می‌کنم؟"or"همیشه به خودم فشار می‌آورم و نمی‌توانم از خودم راضی باشم","answer":"شاید به این دلیل که نمی‌خواهی با احساسات ناخوشایند مواجه بشی. یاد بگیر با خودت رو راست باشی"},
      {"question":"چطور می‌توانم احساس ارزشمندی پیدا کنم؟"or"احساس بی ارزش بودن میکنم","answer":"خودت رو برای همون‌طور که هستی بپذیر و قدر لحظات و دستاوردهای کوچکت رو بدون"},
      {"question":"چرا همه‌چیز برام سخت شده؟"or"همیشه احساس می‌کنم که در زندگی هیچ‌چیز تغییر نمی‌کند و هیچ‌وقت به جلو نمی‌روم","answer":"گاهی فشارهای زندگی باعث می‌شه همه چیز سخت به نظر برسه. سعی کن در هر لحظه قدم‌های کوچکی برداری"},
      {"question":"چرا نمی‌توانم از گذشته رها بشم؟"or"هیچ‌وقت نمی‌توانم از شکست‌هایم عبور کنم و همیشه درگیر اشتباهاتم هستم","answer":"شاید چون هنوز اون موضوعات برایت حل نشده‌اند. باید یاد بگیری که از تجربیات گذشته استفاده کنی، نه اینکه به آن‌ها بچسبی"},
      {"question":"چطور می‌توانم به گذشته نگاه کنم بدون اینکه ناراحت بشم؟"or"همیشه از مشکلات و دردها فرار می‌کنم و هیچ‌وقت به آن‌ها روبه‌رو نمی‌شوم","answer":"باید به‌جای تمرکز بر درد گذشته، درس‌های آن را ببینی و با خودت آشتی کنی"},
      {"question":"چطور می‌توانم بهتر از خودم مراقبت کنم؟"or"نمیتونم از خودم مراقبت کنم","answer":"مراقبت از خود شروع می‌شود از توجه به نیازهای جسمی و عاطفی‌ات. برای خودت زمان اختصاص بده"},
      {"question":"چطور می‌توانم با افراد سمی کنار بیام؟"or"هیچ‌وقت نمی‌توانم مهارت‌های اجتماعی خوبی داشته باشم و همیشه در ارتباطات اجتماعی مشکل دارم","answer":"گر امکانش باشه، از آن‌ها فاصله بگیر. اگر نه، باید مرزهای سالم ایجاد کنی"},
      {"question":"چرا بعضی وقت‌ها احساس می‌کنم تنها کسی هستم که این مشکلات رو دارم؟"or"همیشه حس میکنم فقط من مشکل دارم","answer":"همه مردم درگیر مشکلات خودشان هستند. احساسات مشابه در دیگران هم وجود دارد، فقط ممکنه پنهان باشند"},
      {"question":"چرا بعضی وقت‌ها خیلی حس می‌کنم نمی‌توانم به خودم اعتماد کنم؟"or"به خودم اعتماد ندارم"or"همیشه از خودم انتقاد می‌کنم و هیچ‌وقت از خودم راضی نیستم","answer":"اعتماد به نفس به مرور ایجاد میشه. باید به خودت فرصت‌های کوچک بدهی تا خودتو ثابت کنی"},
      {"question":"چطور می‌توانم با شکست‌هایم کنار بیام؟"or"با شکست هام کنار نمیام","answer":"شکست‌ها بخشی از مسیر هستند. از هر شکست، درس بگیر و حرکت کن"},
      {"question":"چرا گاهی در روابط عاطفی احساس می‌کنم گم می‌شوم؟"or"هیچ‌وقت نمی‌توانم از روابط عاطفی سالم برخوردار باشم و همیشه احساس می‌کنم که در روابط گم می‌شوم","answer":"ممکنه نیاز به فضای شخصی داشته باشی. مرزهای واضح در روابط می‌تواند کمک‌کننده باشد"},
      {"question":"چطور می‌توانم بیشتر از لحظات حال لذت ببرم؟"or"نمیتونم تو لحظه زندگی کنم","answer":"به جای نگرانی از آینده یا پشیمانی از گذشته، به لحظات حال توجه کن و از آن‌ها لذت ببر"},
      {"question":"چرا گاهی احساس می‌کنم به خودم خیانت می‌کنم؟"or"گاهی حس میکنم با خودم کنار نمیام","answer":"شاید به ارزش‌های خودت وفادار نباشی. بررسی کن که آیا رفتارهای تو با باورهایت همخوانی دارند"},
      {"question":"چرا احساس می‌کنم همیشه باید مسئولیت همه‌چیز رو بر عهده بگیرم؟"or"همیشه احساس مسئولیت زیاد میکنم","answer":" این ممکنه به دلیل نگرانی بیش از حد برای دیگران باشه. باید مرزهای سالم داشته باشی"},
      {"question":"چطور می‌توانم بیشتر اعتماد به نفس پیدا کنم؟"or"اعتماد به نفس پایینی دارم","answer":"با تمرین در موقعیت‌های مختلف و تایید موفقیت‌های کوچک می‌توانی اعتماد به نفس خودت رو بالا ببری"},
      {"question":"چطور می‌توانم خودم را بیشتر ببخشم؟"or"نمیتونم خودم و دیگران ببخشم","answer":"باید از اشتباهاتت درس بگیری و به خودت اجازه بدهی که انسان باشی"},
      {"question":"چرا گاهی از روابط فرار می‌کنم؟"or"از روابط فرار میکنم","answer":"شاید ترس از آسیب‌پذیری یا عدم امنیت باعث این رفتار بشه. باید در روابط به خودت و دیگران اعتماد کنی"},
      {"question":"چرا در بعضی مواقع نمی‌توانم تصمیمات درستی بگیرم؟"or"چطوری در بعضی مواقع نمی‌توانم تصمیمات درستی بگیرم؟","answer":"شاید ترس از اشتباه و یا نداشتن اعتماد به نفس باعث این مشکل بشه. باید از تجربه و احساساتت کمک بگیری"},
      {"question":"چطور می‌توانم از خودم انتقاد کمتری بکنم؟"or"همیشه از خودم انتقاد میکنم","answer":"سعی کن بیشتر از خودت حمایت کنی و در موقعیت‌های چالش‌برانگیز از خودت سوالات مثبت بپرسی"},
      {"question":"چرا گاهی از پیگیری اهدافم خسته می‌شوم؟"or"اهدافم را زود ول میکنم","answer":"رسیدن به هدف نیاز به صبر و پشتکار داره. گاهی هم استراحت و تجدید انرژی کمک می‌کنه"},
      {"question":"چرا احساس می‌کنم همیشه در حال دویدن هستم؟"or"حس میکنم دارم درجا میزنم","answer":"شاید درگیر مسئولیت‌های زیادی باشی. باید اولویت‌ها رو مرتب کنی و به خودت وقت بدهی"},
      {"question":"چرا بعضی وقت‌ها احساس می‌کنم خودم رو گم کردم؟"or"خودمو گم کردم","answer":"این می‌تواند نشانه‌ای از فقدان هدف یا جهت در زندگی باشد. باید به مرور اهداف واضح‌تری برای خودت مشخص کنی"},
      {"question":"چرا احساس می‌کنم زندگی به هیچ‌کجا نمی‌ره؟"or"زندگی برام بی معنیه","answer":"ممکنه به دلیل عدم جهت‌گیری یا فشارهای زیاد باشه. با تعیین اهداف کوتاه‌مدت می‌تونی تغییر رو حس کنی"},
      {"question":"چطور می‌توانم از شر استرس خلاص بشم؟"or"چطوری استرسمو کم کنم؟","answer":"تمرین‌های آرامش‌بخش مثل یوگا یا پیاده‌روی می‌تواند بسیار مفید باشد"},
      {"question":"چطور می‌توانم بیشتر از دیگران حمایت کنم؟"or"نمیتونم دیگران درک کنم","answer":"با شنیدن و درک نیازهای دیگران و حمایت عاطفی، می‌توانی روابط بهتری بسازی"},
      {"question":"همیشه گریه میکنم"or"جدیدا خیلی گریه میکنم","answer":"گاهی اوقات گریه کردن بی دلیل شرایطی گذراست و بدون این که مساله‌ساز شود، خاتمه می یابد. اما اگر با تغییرات احساسی شدید مواجه هستید که زندگی را برای شما دشوار کرده است، ریشه یابی و کشف دلیل این شرایط اهمیت دارد که ممکن است از کمبوده خواب و بی پباتی عاطفی باشد"},
      {"question":"چطوری گذشت رو فراموش کنم؟"or"نمیتونم گذشت رو رها کنم","answer":"برای فراموش کردن گذشته، طرز فکر خود را تغییر دهید یا ارتباط خود را با برخی از دوستان قطع کنید یا برای خود هدف تعیین کنید یا بخشیدن را بیاموزید یا  تلاش برای تحت تاثیر قرار دادن مردم را متوقف کنید"},
      {"question":"نمیتونم با خانواده کنار بیام"or"مشکلات خانوادگی دارم","answer":"اگر از یک روانشناس مشکلات خانوادگی در مورد مسائل خانوادگی که مردم با آنها روبرو هستند سوال کنید، به شما خواهند گفت که مشکلات هر خانواده ای متفاوتی است. نمی توان صرفا یک دسته مشخص از انواع مشکلات خانوادگی را برای همه خانواده ها پیدا کرد. مشاور باید متناسب با مشکلات هر خانواده ای برای آنها راه حل مناسب ارائه دهد. اما می توان به طور کلی برخی از رایج ترین مشکلات خانوادگی را طبق تحقیقاتی که روانشناسان انجام داده اند نام برد. در یک پژوهش مشخص شد که دانستن انواع مشکلات خانوادگی باعث می شود شما بتوانید راه حل مناسبی برای هرکدام پیدا کنید و یک رویارویی مناسب با این نمونه مشکلات خانوادگی داشته باشید"},



]
df = pd.DataFrame(question_bank)

# %%
model = SentenceTransformer("HooshvareLab/bert-fa-zwnj-base")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name HooshvareLab/bert-fa-zwnj-base. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/565 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/473M [00:00<?, ?B/s]
# ...

# %%
def get_embedding(sentences):
  embeddings = model.encode(sentences, convert_to_tensor=True)
  return embeddings

# %%
def find_similar_question(new_question, questions, threshold=0.8):
  embeddings = get_embedding(questions + [new_question])
  cosine_scores = util.pytorch_cos_sim(embeddings[-1], embeddings[:-1])
  max_score = cosine_scores.max().item()
  if max_score >= threshold:
    item = df.iloc[cosine_scores.argmax().item()]
    return item["question"], item["answer"], max_score
  return "نمیتوانم پاسخ دهم سوالتان را به نوعی دیگر بپرسید", "نمیتوانم پاسخ دهم سوالتان را به نوعی دیگر بپرسید", max_score

# %%
while True:
  new_question = input("Enter Question : ")
  if new_question == "exit":
    break
  question, answer, score = find_similar_question(new_question, list(df["question"]), 0.4)
  #print("Matched Question :", question)
  print("MatchedAnswer :", answer)
  #print("Match Score :", score)
  print("-----------------------------------")
# Out:
# Enter Question : چطوری به اهدافم برسم
# MatchedAnswer : تمرین روزانه، یادگیری از تجربیات و پذیرش خودت می‌تونه کمک‌کننده باشه
# -----------------------------------
# Enter Question : مشکلات خانوادگی دارم
# MatchedAnswer : اگر از یک روانشناس مشکلات خانوادگی در مورد مسائل خانوادگی که مردم با آنها روبرو هستند سوال کنید، به شما خواهند گفت که مشکلات هر خانواده ای متفاوتی است. نمی توان صرفا یک دسته مشخص از انواع مشکلات خانوادگی را برای همه خانواده ها پیدا کرد. مشاور باید متناسب با مشکلات هر خانواده ای برای آنها راه حل مناسب ارائه دهد. اما می توان به طور کلی برخی از رایج ترین مشکلات خانوادگی را طبق تحقیقاتی که روانشناسان انجام داده اند نام برد. در یک پژوهش مشخص شد که دانستن انواع مشکلات خانوادگی باعث می شود شما بتوانید راه حل مناسبی برای هرکدام پیدا کنید و یک رویارویی مناسب با این نمونه مشکلات خانوادگی داشته باشید
# -----------------------------------
# Enter Question : حس میکنم خیلی تنهام
# ...
